# %% [markdown]
# # Sinh Viên thực hiện Lab 1 ở Đây

# %% [markdown]
# ## Lab 1 - Bài 1

# %%
# Code lab 1 bài 1 ở đây(
print("Xin chào!")
print("Tôi tên là Nguyễn Quốc Hưng")
print("Tôi đến từ Bình Thuận")
# Out:
# Xin chào!
# Tôi tên là Nguyễn Quốc Hưng
# Tôi đến từ Bình Thuận

# %% [markdown]
# ## Lab 1 - Bài 2

# %%
# Code lab 1  bài 2 ở đây
dai = float(input("Nhập chiều dài : "))
rong = float(input("Nhập chiều rộng : "))
chu_vi=(dai+rong)*2
dien_tich=dai*rong
print("chu vi hình chữ nhật là : ",chu_vi)
print("diện tích hình chữ nhật là : ",dien_tich)
# Out:
# chu vi hình chữ nhật là :  38.0
# diện tích hình chữ nhật là :  90.0

# %% [markdown]
# ## Lab 1 - Bài 3

# %%
# Code lab 1  bài 3 ở đây
song = "Sống"

print("“{} không giận, không khờ không oán trách".format(song))
print("{} mỉm cười, với thử thách chông gai".format(song))
print("{} vươn lên, theo kịp ánh ban mai".format(song))
print("{} chan hòa, với những người chung sống.\n".format(song))
print("{} là động, nhưng lòng luôn bất động".format(song))
print("{} là thương, nhưng lòng chẳng vấn vương".format(song))
print("{} yên vui, danh lợi mãi coi thương".format(song))
print("Tâm bất biến, giữa dòng đời vạn biến.”")
# Out:
# “Sống không giận, không khờ không oán trách
# Sống mỉm cười, với thử thách chông gai
# Sống vươn lên, theo kịp ánh ban mai
# Sống chan hòa, với những người chung sống.
#
# Sống là động, nhưng lòng luôn bất động
# Sống là thương, nhưng lòng chẳng vấn vương
# Sống yên vui, danh lợi mãi coi thương
# Tâm bất biến, giữa dòng đời vạn biến.”

# %% [markdown]
# ## Lab 1 - Bài 4

# %%
# code lab 1 bài 4 ở đây
import math

a = float(input("Nhập hệ số a: "))
b = float(input("Nhập hệ số b: "))
c = float(input("Nhập hệ số c: "))
delta = b**2 - 4*a*c
if delta < 0:
    print("Delta nhỏ hơn 0, phương trình vô nghiệm thực.")
else:
    print("Delta =", delta)
    print("Căn delta =", math.sqrt(delta))
# Out:
# Delta nhỏ hơn 0, phương trình vô nghiệm thực.

# %% [markdown]
# ## Lab 1 - Bài 5: bài tập làm thêm

# %%
# code lab 1  bài làm thêm ở đây 
import math
# Phép tính cơ bản
a = float(input("Nhập số a: "))
b = float(input("Nhập số b: "))
print("cộng: ", a + b)
print("trừ: ", a - b)
print("nhân: ", a * b)
if b != 0:
    print("chia: ", a / b)
else:
    print("Không thể chia cho 0")
# Lũy thừa
x = float(input("Nhập cơ số x: "))
y = float(input("Nhập số mũ y: "))
print("lũy thừa: ", x ** y)
# Căn bậc hai
v = float(input("Nhập số v: "))
if v >= 0:
    print("căn bậc hai: ", math.sqrt(v))
else:
    print("Không thể tính căn bậc hai của số âm")
# Hàm lượng giác
goc = float(input("Nhập góc (độ): "))
rad = math.radians(goc)
print("sin: ", math.sin(rad))
print("cos: ", math.cos(rad))
print("tan: ", math.tan(rad))
# Logarit
so_log = float(input("Nhập số cần tính logarit: "))
if so_log > 0:
    print("Log10:", math.log10(so_log))
    print("Ln:", math.log(so_log))
    co_so = float(input("Nhập cơ số logarit: "))
    if co_so > 0 and co_so != 1:
        print(f"log cơ số {co_so}:", math.log(so_log, co_so))
    else:
        print("Cơ số logarit không hợp lệ")
else:
    print("Không thể tính logarit của số không dương")
# Out:
# cộng:  3.0
# trừ:  -1.0
# nhân:  2.0
# chia:  0.5
# lũy thừa:  81.0
# căn bậc hai:  2.23606797749979
# sin:  0.984807753012208
# cos:  -0.1736481776669303
# tan:  -5.671281819617711
# Log10: 1.6020599913279623
# Ln: 3.6888794541139363
# log cơ số 30.0: 1.084582586709858
